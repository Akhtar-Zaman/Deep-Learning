# %%
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers import Bidirectional


from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r'/content/drive/My Drive/Deep Learning/IRIS/Dataset/Iris1.csv')

X = dataset.iloc[:, :-1]
Y = dataset.iloc[:, -1]

X = X.values.reshape(150, 1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
  # create model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(1, 1)))
model.add(Dense(3, activation='softmax'))
	# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                10400
# _________________________________________________________________
# dense (Dense)                (None, 3)                 153
# =================================================================
# Total params: 10,553
# Trainable params: 10,553
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1021 - accuracy: 0.3583
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0963 - accuracy: 0.3583
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0934 - accuracy: 0.3583
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0927 - accuracy: 0.3583
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0889 - accuracy: 0.3583
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0880 - accuracy: 0.3667
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0847 - accuracy: 0.3583
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0819 - accuracy: 0.3667
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0805 - accuracy: 0.3750
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0795 - accuracy: 0.3667
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0757 - accuracy: 0.3583
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0729 - accuracy: 0.4083
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0708 - accuracy: 0.3917
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0674 - accuracy: 0.4000
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0652 - accuracy: 0.4250
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0620 - accuracy: 0.4167
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0575 - accuracy: 0.4333
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0558 - accuracy: 0.4250
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0509 - accuracy: 0.4500
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0500 - accuracy: 0.4500
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0449 - accuracy: 0.4750
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0399 - accuracy: 0.4083
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0349 - accuracy: 0.4583
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0345 - accuracy: 0.4583
# Epoch 25/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0244 - accuracy: 0.5583
# Epoch 26/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0225 - accuracy: 0.5583
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0182 - accuracy: 0.4750
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0144 - accuracy: 0.5667
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0102 - accuracy: 0.6000
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0009 - accuracy: 0.6833
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9960 - accuracy: 0.6583
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9908 - accuracy: 0.6417
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9864 - accuracy: 0.5833
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9786 - accuracy: 0.6500
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9721 - accuracy: 0.6333
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9663 - accuracy: 0.7083
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9598 - accuracy: 0.7167
# Epoch 38/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9522 - accuracy: 0.7083
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9478 - accuracy: 0.6583
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9422 - accuracy: 0.6583
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9415 - accuracy: 0.6333
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9325 - accuracy: 0.6750
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9263 - accuracy: 0.6667
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9150 - accuracy: 0.7333
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9094 - accuracy: 0.7167
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9071 - accuracy: 0.6833
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8926 - accuracy: 0.7167
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8899 - accuracy: 0.7083
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8812 - accuracy: 0.7250
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8838 - accuracy: 0.6750
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8720 - accuracy: 0.7000
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8663 - accuracy: 0.7333
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8568 - accuracy: 0.6500
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8510 - accuracy: 0.7167
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8475 - accuracy: 0.7250
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8415 - accuracy: 0.7333
# Epoch 57/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8324 - accuracy: 0.6917
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8262 - accuracy: 0.7417
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8210 - accuracy: 0.7250
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8156 - accuracy: 0.7167
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8133 - accuracy: 0.6917
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8085 - accuracy: 0.7083
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8046 - accuracy: 0.6333
# Epoch 64/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7967 - accuracy: 0.7250
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7893 - accuracy: 0.7000
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7863 - accuracy: 0.7250
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7818 - accuracy: 0.6833
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7786 - accuracy: 0.7333
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7778 - accuracy: 0.7000
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7766 - accuracy: 0.6500
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7661 - accuracy: 0.7417
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7666 - accuracy: 0.7250
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7684 - accuracy: 0.7000
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7632 - accuracy: 0.7000
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7547 - accuracy: 0.7000
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7436 - accuracy: 0.7417
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7416 - accuracy: 0.7583
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7426 - accuracy: 0.6917
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7384 - accuracy: 0.6917
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7322 - accuracy: 0.7417
# Epoch 81/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7290 - accuracy: 0.6833
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7272 - accuracy: 0.7583
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7223 - accuracy: 0.7667
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7278 - accuracy: 0.7250
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7185 - accuracy: 0.6750
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7286 - accuracy: 0.7167
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7164 - accuracy: 0.7000
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7082 - accuracy: 0.7667
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7109 - accuracy: 0.6917
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7102 - accuracy: 0.7333
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7026 - accuracy: 0.7250
# Epoch 92/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7086 - accuracy: 0.7500
# Epoch 93/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6990 - accuracy: 0.7083
# Epoch 94/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.7667
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7020 - accuracy: 0.7250
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7022 - accuracy: 0.7333
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.7000
# Epoch 98/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.7500
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.7417
# Epoch 100/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.7417

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 66.67%

# %% [markdown]
# # **Cross Vlaidation**

# %%
dataset = pd.read_csv(r'/content/drive/My Drive/Deep Learning/IRIS/Dataset/Iris1.csv')

X = dataset.iloc[:, :-1]
Y = dataset.iloc[:, -1]
X = X.values.reshape(150, 1, 1)

# %%
# define baseline model
def baseline_model():
	# create model
  model = Sequential()
  model.add(LSTM(50, activation='relu', input_shape=(1, 1)))
  model.add(Dense(1))
  model.add(Dense(3, activation='softmax'))
  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=100, batch_size=5, verbose=0)
kfold = KFold(n_splits=10, shuffle=True)
results = cross_val_score(estimator, X, Y, cv=kfold)
print("Accuracy: %.2f%%" % (results.mean()*100))
print("Starndard daviation: %.2f%%" % (results.std()*100))
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea7c5620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea3ab620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea05b268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea62aa60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea3abb70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea5d52f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f0fea0559d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Accuracy: 71.33%
# Starndard daviation: 13.35%
