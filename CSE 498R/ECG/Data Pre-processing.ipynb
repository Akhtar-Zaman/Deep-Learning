# %% [markdown]
# Merge multiple "csv" file into single one from a particular folder

# %%
# import os
# import glob
# import csv
# import pandas as pd
# os.chdir('/content/drive/My Drive/Deep Learning/ECG/ECG-Dataset/train/')
# all_filenames = [i for i in glob.glob('*.{}'.format('csv'))]

# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# combined_csv.to_csv( "ECG.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv(r'/content/drive/My Drive/Deep Learning/ECG/ECG-Dataset/ECG.csv')

# %%
# print(dataset.shape)
# print(dataset.isnull().values.sum())
# print(dataset.isnull().sum())

dataset_500_signal = dataset[0:5000]

# %%
X = dataset_500_signal.iloc[:, 1:-1]
y = dataset_500_signal.iloc[:, -1]

from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
sc_y = MinMaxScaler()
X = sc_X.fit_transform(X)
Y = sc_y.fit_transform(np.array(y).reshape(-1,1))

# %%
plt.plot(X)
plt.title("ECG (ecg10)")
plt.show()

# %%
dataset=dataset.fillna(1)

# %%
dataset = dataset.replace('P','2', regex=True)

# %%
dataset = dataset.replace('QRS','3', regex=True)

# %%
dataset = dataset.replace('T','4', regex=True)

# %%
print(dataset.shape)
print(dataset.isnull().values.sum())
print(dataset.isnull().sum())
# Out:
# (3371250, 2)
# 0
# Signal    0
# Label     0
# dtype: int64

# %%
dataset
# Out:
#            Signal Label
# 0       -3.392631     2
# 1       -3.296447     2
# 2       -3.164828     2
# 3       -2.962337     2
# 4       -2.744660     2
# ...           ...   ...
# 3371245 -0.035003     3
# 3371246 -0.010620     3
# 3371247  0.009699     3
# 3371248  0.025954     3
# 3371249  0.050337     3
#
# [3371250 rows x 2 columns]

# %%
dataset.to_csv(r'/content/drive/My Drive/Deep Learning/ECG/ECG-Dataset/ECG.csv', encoding='utf-8')
